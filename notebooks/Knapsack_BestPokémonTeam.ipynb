# %% [markdown]
# ## How Many Pokémon Fit?

# %% [markdown]
# Finding the best **Pokémon** team by modeling and solving a knapsack problem with [PokeAPI](https://pokeapi.co/) and `PuLP` optimization Python library

# %%
# !pip install -U pulp plotly==5.22.0
# Out:
# Requirement already satisfied: pulp in d:\workspace\github\shortthirdman\datascience-jupyter-notebooks\dev\lib\site-packages (2.8.0)
# Collecting plotly==5.22.0
#   Downloading plotly-5.22.0-py3-none-any.whl.metadata (7.1 kB)
# Collecting tenacity>=6.2.0 (from plotly==5.22.0)
#   Downloading tenacity-8.5.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in d:\workspace\github\shortthirdman\datascience-jupyter-notebooks\dev\lib\site-packages (from plotly==5.22.0) (24.1)
# Downloading plotly-5.22.0-py3-none-any.whl (16.4 MB)
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.1/16.4 MB 825.8 kB/s eta 0:00:20
#     --------------------------------------- 0.3/16.4 MB 2.5 MB/s eta 0:00:07
#    -- ------------------------------------- 0.8/16.4 MB 5.4 MB/s eta 0:00:03
#    ----- ---------------------------------- 2.2/16.4 MB 10.8 MB/s eta 0:00:02
#    ---------- ----------------------------- 4.3/16.4 MB 17.0 MB/s eta 0:00:01
#    --------------- ------------------------ 6.2/16.4 MB 21.0 MB/s eta 0:00:01
#    --------------------- ------------------ 8.7/16.4 MB 25.2 MB/s eta 0:00:01
#    -------------------------- ------------- 10.9/16.4 MB 40.9 MB/s eta 0:00:01
#    ------------------------------- -------- 12.9/16.4 MB 50.4 MB/s eta 0:00:01
#    ------------------------------------- -- 15.4/16.4 MB 50.4 MB/s eta 0:00:01
#    ---------------------------------------  16.4/16.4 MB 50.4 MB/s eta 0:00:01
#    ---------------------------------------- 16.4/16.4 MB 43.7 MB/s eta 0:00:00
# Downloading tenacity-8.5.0-py3-none-any.whl (28 kB)
# Installing collected packages: tenacity, plotly
# Successfully installed plotly-5.22.0 tenacity-8.5.0
# [notice] A new release of pip is available: 24.0 -> 24.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import requests
import pandas as pd
import pulp

# %%
url = "https://pokeapi.co/api/v2/pokemon?limit=1500"
response = requests.get(url)
data = response.json()
pokemon_urls = [pokemon['url'] for pokemon in data['results']]

counter = 0
pokemon_data = []
for url in pokemon_urls:
    response = requests.get(url)
    pokemon = response.json()
    base_stats = {stat['stat']['name']: stat['base_stat'] for stat in pokemon['stats']}
    pokemon_data.append({
        'name': pokemon['name'],
        'weight': pokemon['weight'],
        'hp': base_stats.get('hp', 0),
        'attack': base_stats.get('attack', 0),
        'defense': base_stats.get('defense', 0),
        'special_attack': base_stats.get('special-attack', 0),
        'special_defense': base_stats.get('special-defense', 0),
        'speed': base_stats.get('speed', 0),
        'type': [t['type']['name'] for t in pokemon['types']],
    })
    counter += 1
    print("Adding {} -> {}".format(counter, pokemon['name']))
# Out:
# Adding 1 -> bulbasaur
# Adding 2 -> ivysaur
# Adding 3 -> venusaur
# Adding 4 -> charmander
# Adding 5 -> charmeleon
# Adding 6 -> charizard
# Adding 7 -> squirtle
# Adding 8 -> wartortle
# Adding 9 -> blastoise
# Adding 10 -> caterpie
# Adding 11 -> metapod
# Adding 12 -> butterfree
# Adding 13 -> weedle
# Adding 14 -> kakuna
# Adding 15 -> beedrill
# Adding 16 -> pidgey
# Adding 17 -> pidgeotto
# Adding 18 -> pidgeot
# Adding 19 -> rattata
# Adding 20 -> raticate
# Adding 21 -> spearow
# Adding 22 -> fearow
# Adding 23 -> ekans
# Adding 24 -> arbok
# Adding 25 -> pikachu
# Adding 26 -> raichu
# Adding 27 -> sandshrew
# Adding 28 -> sandslash
# Adding 29 -> nidoran-f
# Adding 30 -> nidorina
# Adding 31 -> nidoqueen
# Adding 32 -> nidoran-m
# Adding 33 -> nidorino
# Adding 34 -> nidoking
# Adding 35 -> clefairy
# Adding 36 -> clefable
# Adding 37 -> vulpix
# Adding 38 -> ninetales
# Adding 39 -> jigglypuff
# Adding 40 -> wigglytuff
# Adding 41 -> zubat
# Adding 42 -> golbat
# Adding 43 -> oddish
# Adding 44 -> gloom
# Adding 45 -> vileplume
# Adding 46 -> paras
# Adding 47 -> parasect
# Adding 48 -> venonat
# Adding 49 -> venomoth
# Adding 50 -> diglett
# Adding 51 -> dugtrio
# Adding 52 -> meowth
# Adding 53 -> persian
# Adding 54 -> psyduck
# Adding 55 -> golduck
# Adding 56 -> mankey
# Adding 57 -> primeape
# Adding 58 -> growlithe
# Adding 59 -> arcanine
# Adding 60 -> poliwag
# Adding 61 -> poliwhirl
# Adding 62 -> poliwrath
# Adding 63 -> abra
# Adding 64 -> kadabra
# Adding 65 -> alakazam
# Adding 66 -> machop
# Adding 67 -> machoke
# Adding 68 -> machamp
# Adding 69 -> bellsprout
# Adding 70 -> weepinbell
# Adding 71 -> victreebel
# Adding 72 -> tentacool
# Adding 73 -> tentacruel
# Adding 74 -> geodude
# Adding 75 -> graveler
# Adding 76 -> golem
# Adding 77 -> ponyta
# Adding 78 -> rapidash
# Adding 79 -> slowpoke
# Adding 80 -> slowbro
# Adding 81 -> magnemite
# Adding 82 -> magneton
# Adding 83 -> farfetchd
# Adding 84 -> doduo
# Adding 85 -> dodrio
# Adding 86 -> seel
# Adding 87 -> dewgong
# Adding 88 -> grimer
# Adding 89 -> muk
# Adding 90 -> shellder
# Adding 91 -> cloyster
# Adding 92 -> gastly
# Adding 93 -> haunter
# Adding 94 -> gengar
# Adding 95 -> onix
# Adding 96 -> drowzee
# Adding 97 -> hypno
# Adding 98 -> krabby
# Adding 99 -> kingler
# Adding 100 -> voltorb
# Adding 101 -> electrode
# Adding 102 -> exeggcute
# Adding 103 -> exeggutor
# Adding 104 -> cubone
# Adding 105 -> marowak
# Adding 106 -> hitmonlee
# Adding 107 -> hitmonchan
# Adding 108 -> lickitung
# Adding 109 -> koffing
# Adding 110 -> weezing
# Adding 111 -> rhyhorn
# Adding 112 -> rhydon
# Adding 113 -> chansey
# Adding 114 -> tangela
# Adding 115 -> kangaskhan
# Adding 116 -> horsea
# Adding 117 -> seadra
# Adding 118 -> goldeen
# Adding 119 -> seaking
# Adding 120 -> staryu
# Adding 121 -> starmie
# Adding 122 -> mr-mime
# Adding 123 -> scyther
# Adding 124 -> jynx
# Adding 125 -> electabuzz
# Adding 126 -> magmar
# Adding 127 -> pinsir
# Adding 128 -> tauros
# Adding 129 -> magikarp
# Adding 130 -> gyarados
# Adding 131 -> lapras
# Adding 132 -> ditto
# Adding 133 -> eevee
# Adding 134 -> vaporeon
# Adding 135 -> jolteon
# Adding 136 -> flareon
# Adding 137 -> porygon
# Adding 138 -> omanyte
# Adding 139 -> omastar
# Adding 140 -> kabuto
# Adding 141 -> kabutops
# Adding 142 -> aerodactyl
# Adding 143 -> snorlax
# Adding 144 -> articuno
# Adding 145 -> zapdos
# Adding 146 -> moltres
# Adding 147 -> dratini
# Adding 148 -> dragonair
# Adding 149 -> dragonite
# Adding 150 -> mewtwo
# Adding 151 -> mew
# Adding 152 -> chikorita
# Adding 153 -> bayleef
# Adding 154 -> meganium
# Adding 155 -> cyndaquil
# Adding 156 -> quilava
# Adding 157 -> typhlosion
# Adding 158 -> totodile
# Adding 159 -> croconaw
# Adding 160 -> feraligatr
# Adding 161 -> sentret
# Adding 162 -> furret
# Adding 163 -> hoothoot
# Adding 164 -> noctowl
# Adding 165 -> ledyba
# Adding 166 -> ledian
# Adding 167 -> spinarak
# Adding 168 -> ariados
# Adding 169 -> crobat
# Adding 170 -> chinchou
# Adding 171 -> lanturn
# Adding 172 -> pichu
# Adding 173 -> cleffa
# Adding 174 -> igglybuff
# Adding 175 -> togepi
# Adding 176 -> togetic
# Adding 177 -> natu
# Adding 178 -> xatu
# Adding 179 -> mareep
# Adding 180 -> flaaffy
# Adding 181 -> ampharos
# Adding 182 -> bellossom
# Adding 183 -> marill
# Adding 184 -> azumarill
# Adding 185 -> sudowoodo
# Adding 186 -> politoed
# Adding 187 -> hoppip
# Adding 188 -> skiploom
# Adding 189 -> jumpluff
# Adding 190 -> aipom
# Adding 191 -> sunkern
# Adding 192 -> sunflora
# Adding 193 -> yanma
# Adding 194 -> wooper
# Adding 195 -> quagsire
# Adding 196 -> espeon
# Adding 197 -> umbreon
# Adding 198 -> murkrow
# Adding 199 -> slowking
# Adding 200 -> misdreavus
# Adding 201 -> unown
# Adding 202 -> wobbuffet
# Adding 203 -> girafarig
# Adding 204 -> pineco
# Adding 205 -> forretress
# Adding 206 -> dunsparce
# Adding 207 -> gligar
# Adding 208 -> steelix
# Adding 209 -> snubbull
# Adding 210 -> granbull
# Adding 211 -> qwilfish
# Adding 212 -> scizor
# Adding 213 -> shuckle
# Adding 214 -> heracross
# Adding 215 -> sneasel
# Adding 216 -> teddiursa
# Adding 217 -> ursaring
# Adding 218 -> slugma
# Adding 219 -> magcargo
# Adding 220 -> swinub
# Adding 221 -> piloswine
# Adding 222 -> corsola
# Adding 223 -> remoraid
# Adding 224 -> octillery
# Adding 225 -> delibird
# Adding 226 -> mantine
# Adding 227 -> skarmory
# Adding 228 -> houndour
# Adding 229 -> houndoom
# Adding 230 -> kingdra
# Adding 231 -> phanpy
# Adding 232 -> donphan
# Adding 233 -> porygon2
# Adding 234 -> stantler
# Adding 235 -> smeargle
# Adding 236 -> tyrogue
# Adding 237 -> hitmontop
# Adding 238 -> smoochum
# Adding 239 -> elekid
# Adding 240 -> magby
# Adding 241 -> miltank
# Adding 242 -> blissey
# Adding 243 -> raikou
# Adding 244 -> entei
# Adding 245 -> suicune
# Adding 246 -> larvitar
# Adding 247 -> pupitar
# Adding 248 -> tyranitar
# Adding 249 -> lugia
# Adding 250 -> ho-oh
# Adding 251 -> celebi
# Adding 252 -> treecko
# Adding 253 -> grovyle
# Adding 254 -> sceptile
# Adding 255 -> torchic
# Adding 256 -> combusken
# Adding 257 -> blaziken
# Adding 258 -> mudkip
# Adding 259 -> marshtomp
# Adding 260 -> swampert
# Adding 261 -> poochyena
# Adding 262 -> mightyena
# Adding 263 -> zigzagoon
# Adding 264 -> linoone
# Adding 265 -> wurmple
# Adding 266 -> silcoon
# Adding 267 -> beautifly
# Adding 268 -> cascoon
# Adding 269 -> dustox
# Adding 270 -> lotad
# Adding 271 -> lombre
# Adding 272 -> ludicolo
# Adding 273 -> seedot
# Adding 274 -> nuzleaf
# Adding 275 -> shiftry
# Adding 276 -> taillow
# Adding 277 -> swellow
# Adding 278 -> wingull
# Adding 279 -> pelipper
# Adding 280 -> ralts
# Adding 281 -> kirlia
# Adding 282 -> gardevoir
# Adding 283 -> surskit
# Adding 284 -> masquerain
# Adding 285 -> shroomish
# Adding 286 -> breloom
# Adding 287 -> slakoth
# Adding 288 -> vigoroth
# Adding 289 -> slaking
# Adding 290 -> nincada
# Adding 291 -> ninjask
# Adding 292 -> shedinja
# Adding 293 -> whismur
# Adding 294 -> loudred
# Adding 295 -> exploud
# Adding 296 -> makuhita
# Adding 297 -> hariyama
# Adding 298 -> azurill
# Adding 299 -> nosepass
# Adding 300 -> skitty
# Adding 301 -> delcatty
# Adding 302 -> sableye
# Adding 303 -> mawile
# Adding 304 -> aron
# Adding 305 -> lairon
# Adding 306 -> aggron
# Adding 307 -> meditite
# Adding 308 -> medicham
# Adding 309 -> electrike
# Adding 310 -> manectric
# Adding 311 -> plusle
# Adding 312 -> minun
# Adding 313 -> volbeat
# Adding 314 -> illumise
# Adding 315 -> roselia
# Adding 316 -> gulpin
# Adding 317 -> swalot
# Adding 318 -> carvanha
# Adding 319 -> sharpedo
# Adding 320 -> wailmer
# Adding 321 -> wailord
# Adding 322 -> numel
# Adding 323 -> camerupt
# Adding 324 -> torkoal
# Adding 325 -> spoink
# Adding 326 -> grumpig
# Adding 327 -> spinda
# Adding 328 -> trapinch
# Adding 329 -> vibrava
# Adding 330 -> flygon
# Adding 331 -> cacnea
# Adding 332 -> cacturne
# Adding 333 -> swablu
# Adding 334 -> altaria
# Adding 335 -> zangoose
# Adding 336 -> seviper
# Adding 337 -> lunatone
# Adding 338 -> solrock
# Adding 339 -> barboach
# Adding 340 -> whiscash
# Adding 341 -> corphish
# Adding 342 -> crawdaunt
# Adding 343 -> baltoy
# Adding 344 -> claydol
# Adding 345 -> lileep
# Adding 346 -> cradily
# Adding 347 -> anorith
# Adding 348 -> armaldo
# Adding 349 -> feebas
# Adding 350 -> milotic
# Adding 351 -> castform
# Adding 352 -> kecleon
# Adding 353 -> shuppet
# Adding 354 -> banette
# Adding 355 -> duskull
# Adding 356 -> dusclops
# Adding 357 -> tropius
# Adding 358 -> chimecho
# Adding 359 -> absol
# Adding 360 -> wynaut
# Adding 361 -> snorunt
# Adding 362 -> glalie
# Adding 363 -> spheal
# Adding 364 -> sealeo
# Adding 365 -> walrein
# Adding 366 -> clamperl
# Adding 367 -> huntail
# Adding 368 -> gorebyss
# Adding 369 -> relicanth
# Adding 370 -> luvdisc
# Adding 371 -> bagon
# Adding 372 -> shelgon
# Adding 373 -> salamence
# Adding 374 -> beldum
# Adding 375 -> metang
# Adding 376 -> metagross
# Adding 377 -> regirock
# Adding 378 -> regice
# Adding 379 -> registeel
# Adding 380 -> latias
# Adding 381 -> latios
# Adding 382 -> kyogre
# Adding 383 -> groudon
# Adding 384 -> rayquaza
# Adding 385 -> jirachi
# Adding 386 -> deoxys-normal
# Adding 387 -> turtwig
# Adding 388 -> grotle
# Adding 389 -> torterra
# Adding 390 -> chimchar
# Adding 391 -> monferno
# Adding 392 -> infernape
# Adding 393 -> piplup
# Adding 394 -> prinplup
# Adding 395 -> empoleon
# Adding 396 -> starly
# Adding 397 -> staravia
# Adding 398 -> staraptor
# Adding 399 -> bidoof
# Adding 400 -> bibarel
# Adding 401 -> kricketot
# Adding 402 -> kricketune
# Adding 403 -> shinx
# Adding 404 -> luxio
# Adding 405 -> luxray
# Adding 406 -> budew
# Adding 407 -> roserade
# Adding 408 -> cranidos
# Adding 409 -> rampardos
# Adding 410 -> shieldon
# Adding 411 -> bastiodon
# Adding 412 -> burmy
# Adding 413 -> wormadam-plant
# Adding 414 -> mothim
# Adding 415 -> combee
# Adding 416 -> vespiquen
# Adding 417 -> pachirisu
# Adding 418 -> buizel
# Adding 419 -> floatzel
# Adding 420 -> cherubi
# Adding 421 -> cherrim
# Adding 422 -> shellos
# Adding 423 -> gastrodon
# Adding 424 -> ambipom
# Adding 425 -> drifloon
# Adding 426 -> drifblim
# Adding 427 -> buneary
# Adding 428 -> lopunny
# Adding 429 -> mismagius
# Adding 430 -> honchkrow
# Adding 431 -> glameow
# Adding 432 -> purugly
# Adding 433 -> chingling
# Adding 434 -> stunky
# Adding 435 -> skuntank
# Adding 436 -> bronzor
# Adding 437 -> bronzong
# Adding 438 -> bonsly
# Adding 439 -> mime-jr
# Adding 440 -> happiny
# Adding 441 -> chatot
# Adding 442 -> spiritomb
# Adding 443 -> gible
# Adding 444 -> gabite
# Adding 445 -> garchomp
# Adding 446 -> munchlax
# Adding 447 -> riolu
# Adding 448 -> lucario
# Adding 449 -> hippopotas
# Adding 450 -> hippowdon
# Adding 451 -> skorupi
# Adding 452 -> drapion
# Adding 453 -> croagunk
# Adding 454 -> toxicroak
# Adding 455 -> carnivine
# Adding 456 -> finneon
# Adding 457 -> lumineon
# Adding 458 -> mantyke
# Adding 459 -> snover
# Adding 460 -> abomasnow
# Adding 461 -> weavile
# Adding 462 -> magnezone
# Adding 463 -> lickilicky
# Adding 464 -> rhyperior
# Adding 465 -> tangrowth
# Adding 466 -> electivire
# Adding 467 -> magmortar
# Adding 468 -> togekiss
# Adding 469 -> yanmega
# Adding 470 -> leafeon
# Adding 471 -> glaceon
# Adding 472 -> gliscor
# Adding 473 -> mamoswine
# Adding 474 -> porygon-z
# Adding 475 -> gallade
# Adding 476 -> probopass
# Adding 477 -> dusknoir
# Adding 478 -> froslass
# Adding 479 -> rotom
# Adding 480 -> uxie
# Adding 481 -> mesprit
# Adding 482 -> azelf
# Adding 483 -> dialga
# Adding 484 -> palkia
# Adding 485 -> heatran
# Adding 486 -> regigigas
# Adding 487 -> giratina-altered
# Adding 488 -> cresselia
# Adding 489 -> phione
# Adding 490 -> manaphy
# Adding 491 -> darkrai
# Adding 492 -> shaymin-land
# Adding 493 -> arceus
# Adding 494 -> victini
# Adding 495 -> snivy
# Adding 496 -> servine
# Adding 497 -> serperior
# Adding 498 -> tepig
# Adding 499 -> pignite
# Adding 500 -> emboar
# Adding 501 -> oshawott
# Adding 502 -> dewott
# Adding 503 -> samurott
# Adding 504 -> patrat
# Adding 505 -> watchog
# Adding 506 -> lillipup
# Adding 507 -> herdier
# Adding 508 -> stoutland
# Adding 509 -> purrloin
# Adding 510 -> liepard
# Adding 511 -> pansage
# Adding 512 -> simisage
# Adding 513 -> pansear
# Adding 514 -> simisear
# Adding 515 -> panpour
# Adding 516 -> simipour
# Adding 517 -> munna
# Adding 518 -> musharna
# Adding 519 -> pidove
# Adding 520 -> tranquill
# Adding 521 -> unfezant
# Adding 522 -> blitzle
# Adding 523 -> zebstrika
# Adding 524 -> roggenrola
# Adding 525 -> boldore
# Adding 526 -> gigalith
# Adding 527 -> woobat
# Adding 528 -> swoobat
# Adding 529 -> drilbur
# Adding 530 -> excadrill
# Adding 531 -> audino
# Adding 532 -> timburr
# Adding 533 -> gurdurr
# Adding 534 -> conkeldurr
# Adding 535 -> tympole
# Adding 536 -> palpitoad
# Adding 537 -> seismitoad
# Adding 538 -> throh
# Adding 539 -> sawk
# Adding 540 -> sewaddle
# Adding 541 -> swadloon
# Adding 542 -> leavanny
# Adding 543 -> venipede
# Adding 544 -> whirlipede
# Adding 545 -> scolipede
# Adding 546 -> cottonee
# Adding 547 -> whimsicott
# Adding 548 -> petilil
# Adding 549 -> lilligant
# Adding 550 -> basculin-red-striped
# Adding 551 -> sandile
# Adding 552 -> krokorok
# Adding 553 -> krookodile
# Adding 554 -> darumaka
# Adding 555 -> darmanitan-standard
# Adding 556 -> maractus
# Adding 557 -> dwebble
# Adding 558 -> crustle
# Adding 559 -> scraggy
# Adding 560 -> scrafty
# Adding 561 -> sigilyph
# Adding 562 -> yamask
# Adding 563 -> cofagrigus
# Adding 564 -> tirtouga
# Adding 565 -> carracosta
# Adding 566 -> archen
# Adding 567 -> archeops
# Adding 568 -> trubbish
# Adding 569 -> garbodor
# Adding 570 -> zorua
# Adding 571 -> zoroark
# Adding 572 -> minccino
# Adding 573 -> cinccino
# Adding 574 -> gothita
# Adding 575 -> gothorita
# Adding 576 -> gothitelle
# Adding 577 -> solosis
# Adding 578 -> duosion
# Adding 579 -> reuniclus
# Adding 580 -> ducklett
# Adding 581 -> swanna
# Adding 582 -> vanillite
# Adding 583 -> vanillish
# Adding 584 -> vanilluxe
# Adding 585 -> deerling
# Adding 586 -> sawsbuck
# Adding 587 -> emolga
# Adding 588 -> karrablast
# Adding 589 -> escavalier
# Adding 590 -> foongus
# Adding 591 -> amoonguss
# Adding 592 -> frillish
# Adding 593 -> jellicent
# Adding 594 -> alomomola
# Adding 595 -> joltik
# Adding 596 -> galvantula
# Adding 597 -> ferroseed
# Adding 598 -> ferrothorn
# Adding 599 -> klink
# Adding 600 -> klang
# Adding 601 -> klinklang
# Adding 602 -> tynamo
# Adding 603 -> eelektrik
# Adding 604 -> eelektross
# Adding 605 -> elgyem
# Adding 606 -> beheeyem
# Adding 607 -> litwick
# Adding 608 -> lampent
# Adding 609 -> chandelure
# Adding 610 -> axew
# Adding 611 -> fraxure
# Adding 612 -> haxorus
# Adding 613 -> cubchoo
# Adding 614 -> beartic
# Adding 615 -> cryogonal
# Adding 616 -> shelmet
# Adding 617 -> accelgor
# Adding 618 -> stunfisk
# Adding 619 -> mienfoo
# Adding 620 -> mienshao
# Adding 621 -> druddigon
# Adding 622 -> golett
# Adding 623 -> golurk
# Adding 624 -> pawniard
# Adding 625 -> bisharp
# Adding 626 -> bouffalant
# Adding 627 -> rufflet
# Adding 628 -> braviary
# Adding 629 -> vullaby
# Adding 630 -> mandibuzz
# Adding 631 -> heatmor
# Adding 632 -> durant
# Adding 633 -> deino
# Adding 634 -> zweilous
# Adding 635 -> hydreigon
# Adding 636 -> larvesta
# Adding 637 -> volcarona
# Adding 638 -> cobalion
# Adding 639 -> terrakion
# Adding 640 -> virizion
# Adding 641 -> tornadus-incarnate
# Adding 642 -> thundurus-incarnate
# Adding 643 -> reshiram
# Adding 644 -> zekrom
# Adding 645 -> landorus-incarnate
# Adding 646 -> kyurem
# Adding 647 -> keldeo-ordinary
# Adding 648 -> meloetta-aria
# Adding 649 -> genesect
# Adding 650 -> chespin
# Adding 651 -> quilladin
# Adding 652 -> chesnaught
# Adding 653 -> fennekin
# Adding 654 -> braixen
# Adding 655 -> delphox
# Adding 656 -> froakie
# Adding 657 -> frogadier
# Adding 658 -> greninja
# Adding 659 -> bunnelby
# Adding 660 -> diggersby
# Adding 661 -> fletchling
# Adding 662 -> fletchinder
# Adding 663 -> talonflame
# Adding 664 -> scatterbug
# Adding 665 -> spewpa
# Adding 666 -> vivillon
# Adding 667 -> litleo
# Adding 668 -> pyroar
# Adding 669 -> flabebe
# Adding 670 -> floette
# Adding 671 -> florges
# Adding 672 -> skiddo
# Adding 673 -> gogoat
# Adding 674 -> pancham
# Adding 675 -> pangoro
# Adding 676 -> furfrou
# Adding 677 -> espurr
# Adding 678 -> meowstic-male
# Adding 679 -> honedge
# Adding 680 -> doublade
# Adding 681 -> aegislash-shield
# Adding 682 -> spritzee
# Adding 683 -> aromatisse
# Adding 684 -> swirlix
# Adding 685 -> slurpuff
# Adding 686 -> inkay
# Adding 687 -> malamar
# Adding 688 -> binacle
# Adding 689 -> barbaracle
# Adding 690 -> skrelp
# Adding 691 -> dragalge
# Adding 692 -> clauncher
# Adding 693 -> clawitzer
# Adding 694 -> helioptile
# Adding 695 -> heliolisk
# Adding 696 -> tyrunt
# Adding 697 -> tyrantrum
# Adding 698 -> amaura
# Adding 699 -> aurorus
# Adding 700 -> sylveon
# Adding 701 -> hawlucha
# Adding 702 -> dedenne
# Adding 703 -> carbink
# Adding 704 -> goomy
# Adding 705 -> sliggoo
# Adding 706 -> goodra
# Adding 707 -> klefki
# Adding 708 -> phantump
# Adding 709 -> trevenant
# Adding 710 -> pumpkaboo-average
# Adding 711 -> gourgeist-average
# Adding 712 -> bergmite
# Adding 713 -> avalugg
# Adding 714 -> noibat
# Adding 715 -> noivern
# Adding 716 -> xerneas
# Adding 717 -> yveltal
# Adding 718 -> zygarde-50
# Adding 719 -> diancie
# Adding 720 -> hoopa
# Adding 721 -> volcanion
# Adding 722 -> rowlet
# Adding 723 -> dartrix
# Adding 724 -> decidueye
# Adding 725 -> litten
# Adding 726 -> torracat
# Adding 727 -> incineroar
# Adding 728 -> popplio
# Adding 729 -> brionne
# Adding 730 -> primarina
# Adding 731 -> pikipek
# Adding 732 -> trumbeak
# Adding 733 -> toucannon
# Adding 734 -> yungoos
# Adding 735 -> gumshoos
# Adding 736 -> grubbin
# Adding 737 -> charjabug
# Adding 738 -> vikavolt
# Adding 739 -> crabrawler
# Adding 740 -> crabominable
# Adding 741 -> oricorio-baile
# Adding 742 -> cutiefly
# Adding 743 -> ribombee
# Adding 744 -> rockruff
# Adding 745 -> lycanroc-midday
# Adding 746 -> wishiwashi-solo
# Adding 747 -> mareanie
# Adding 748 -> toxapex
# Adding 749 -> mudbray
# Adding 750 -> mudsdale
# Adding 751 -> dewpider
# Adding 752 -> araquanid
# Adding 753 -> fomantis
# Adding 754 -> lurantis
# Adding 755 -> morelull
# Adding 756 -> shiinotic
# Adding 757 -> salandit
# Adding 758 -> salazzle
# Adding 759 -> stufful
# Adding 760 -> bewear
# Adding 761 -> bounsweet
# Adding 762 -> steenee
# Adding 763 -> tsareena
# Adding 764 -> comfey
# Adding 765 -> oranguru
# Adding 766 -> passimian
# Adding 767 -> wimpod
# Adding 768 -> golisopod
# Adding 769 -> sandygast
# Adding 770 -> palossand
# Adding 771 -> pyukumuku
# Adding 772 -> type-null
# Adding 773 -> silvally
# Adding 774 -> minior-red-meteor
# Adding 775 -> komala
# Adding 776 -> turtonator
# Adding 777 -> togedemaru
# Adding 778 -> mimikyu-disguised
# Adding 779 -> bruxish
# Adding 780 -> drampa
# Adding 781 -> dhelmise
# Adding 782 -> jangmo-o
# Adding 783 -> hakamo-o
# Adding 784 -> kommo-o
# Adding 785 -> tapu-koko
# Adding 786 -> tapu-lele
# Adding 787 -> tapu-bulu
# Adding 788 -> tapu-fini
# Adding 789 -> cosmog
# Adding 790 -> cosmoem
# Adding 791 -> solgaleo
# Adding 792 -> lunala
# Adding 793 -> nihilego
# Adding 794 -> buzzwole
# Adding 795 -> pheromosa
# Adding 796 -> xurkitree
# Adding 797 -> celesteela
# Adding 798 -> kartana
# Adding 799 -> guzzlord
# Adding 800 -> necrozma
# Adding 801 -> magearna
# Adding 802 -> marshadow
# Adding 803 -> poipole
# Adding 804 -> naganadel
# Adding 805 -> stakataka
# Adding 806 -> blacephalon
# Adding 807 -> zeraora
# Adding 808 -> meltan
# Adding 809 -> melmetal
# Adding 810 -> grookey
# Adding 811 -> thwackey
# Adding 812 -> rillaboom
# Adding 813 -> scorbunny
# Adding 814 -> raboot
# Adding 815 -> cinderace
# Adding 816 -> sobble
# Adding 817 -> drizzile
# Adding 818 -> inteleon
# Adding 819 -> skwovet
# Adding 820 -> greedent
# Adding 821 -> rookidee
# Adding 822 -> corvisquire
# Adding 823 -> corviknight
# Adding 824 -> blipbug
# Adding 825 -> dottler
# Adding 826 -> orbeetle
# Adding 827 -> nickit
# Adding 828 -> thievul
# Adding 829 -> gossifleur
# Adding 830 -> eldegoss
# Adding 831 -> wooloo
# Adding 832 -> dubwool
# Adding 833 -> chewtle
# Adding 834 -> drednaw
# Adding 835 -> yamper
# Adding 836 -> boltund
# Adding 837 -> rolycoly
# Adding 838 -> carkol
# Adding 839 -> coalossal
# Adding 840 -> applin
# Adding 841 -> flapple
# Adding 842 -> appletun
# Adding 843 -> silicobra
# Adding 844 -> sandaconda
# Adding 845 -> cramorant
# Adding 846 -> arrokuda
# Adding 847 -> barraskewda
# Adding 848 -> toxel
# Adding 849 -> toxtricity-amped
# Adding 850 -> sizzlipede
# Adding 851 -> centiskorch
# Adding 852 -> clobbopus
# Adding 853 -> grapploct
# Adding 854 -> sinistea
# Adding 855 -> polteageist
# Adding 856 -> hatenna
# Adding 857 -> hattrem
# Adding 858 -> hatterene
# Adding 859 -> impidimp
# Adding 860 -> morgrem
# Adding 861 -> grimmsnarl
# Adding 862 -> obstagoon
# Adding 863 -> perrserker
# Adding 864 -> cursola
# Adding 865 -> sirfetchd
# Adding 866 -> mr-rime
# Adding 867 -> runerigus
# Adding 868 -> milcery
# Adding 869 -> alcremie
# Adding 870 -> falinks
# Adding 871 -> pincurchin
# Adding 872 -> snom
# Adding 873 -> frosmoth
# Adding 874 -> stonjourner
# Adding 875 -> eiscue-ice
# Adding 876 -> indeedee-male
# Adding 877 -> morpeko-full-belly
# Adding 878 -> cufant
# Adding 879 -> copperajah
# Adding 880 -> dracozolt
# Adding 881 -> arctozolt
# Adding 882 -> dracovish
# Adding 883 -> arctovish
# Adding 884 -> duraludon
# Adding 885 -> dreepy
# Adding 886 -> drakloak
# Adding 887 -> dragapult
# Adding 888 -> zacian
# Adding 889 -> zamazenta
# Adding 890 -> eternatus
# Adding 891 -> kubfu
# Adding 892 -> urshifu-single-strike
# Adding 893 -> zarude
# Adding 894 -> regieleki
# Adding 895 -> regidrago
# Adding 896 -> glastrier
# Adding 897 -> spectrier
# Adding 898 -> calyrex
# Adding 899 -> wyrdeer
# Adding 900 -> kleavor
# Adding 901 -> ursaluna
# Adding 902 -> basculegion-male
# Adding 903 -> sneasler
# Adding 904 -> overqwil
# Adding 905 -> enamorus-incarnate
# Adding 906 -> sprigatito
# Adding 907 -> floragato
# Adding 908 -> meowscarada
# Adding 909 -> fuecoco
# Adding 910 -> crocalor
# Adding 911 -> skeledirge
# Adding 912 -> quaxly
# Adding 913 -> quaxwell
# Adding 914 -> quaquaval
# Adding 915 -> lechonk
# Adding 916 -> oinkologne
# Adding 917 -> tarountula
# Adding 918 -> spidops
# Adding 919 -> nymble
# Adding 920 -> lokix
# Adding 921 -> pawmi
# Adding 922 -> pawmo
# Adding 923 -> pawmot
# Adding 924 -> tandemaus
# Adding 925 -> maushold
# Adding 926 -> fidough
# Adding 927 -> dachsbun
# Adding 928 -> smoliv
# Adding 929 -> dolliv
# Adding 930 -> arboliva
# Adding 931 -> squawkabilly
# Adding 932 -> nacli
# Adding 933 -> naclstack
# Adding 934 -> garganacl
# Adding 935 -> charcadet
# Adding 936 -> armarouge
# Adding 937 -> ceruledge
# Adding 938 -> tadbulb
# Adding 939 -> bellibolt
# Adding 940 -> wattrel
# Adding 941 -> kilowattrel
# Adding 942 -> maschiff
# Adding 943 -> mabosstiff
# Adding 944 -> shroodle
# Adding 945 -> grafaiai
# Adding 946 -> bramblin
# Adding 947 -> brambleghast
# Adding 948 -> toedscool
# Adding 949 -> toedscruel
# Adding 950 -> klawf
# Adding 951 -> capsakid
# Adding 952 -> scovillain
# Adding 953 -> rellor
# Adding 954 -> rabsca
# Adding 955 -> flittle
# Adding 956 -> espathra
# Adding 957 -> tinkatink
# Adding 958 -> tinkatuff
# Adding 959 -> tinkaton
# Adding 960 -> wiglett
# Adding 961 -> wugtrio
# Adding 962 -> bombirdier
# Adding 963 -> finizen
# Adding 964 -> palafin
# Adding 965 -> varoom
# Adding 966 -> revavroom
# Adding 967 -> cyclizar
# Adding 968 -> orthworm
# Adding 969 -> glimmet
# Adding 970 -> glimmora
# Adding 971 -> greavard
# Adding 972 -> houndstone
# Adding 973 -> flamigo
# Adding 974 -> cetoddle
# Adding 975 -> cetitan
# Adding 976 -> veluza
# Adding 977 -> dondozo
# Adding 978 -> tatsugiri
# Adding 979 -> annihilape
# Adding 980 -> clodsire
# Adding 981 -> farigiraf
# Adding 982 -> dudunsparce
# Adding 983 -> kingambit
# Adding 984 -> great-tusk
# Adding 985 -> scream-tail
# Adding 986 -> brute-bonnet
# Adding 987 -> flutter-mane
# Adding 988 -> slither-wing
# Adding 989 -> sandy-shocks
# Adding 990 -> iron-treads
# Adding 991 -> iron-bundle
# Adding 992 -> iron-hands
# Adding 993 -> iron-jugulis
# Adding 994 -> iron-moth
# Adding 995 -> iron-thorns
# Adding 996 -> frigibax
# Adding 997 -> arctibax
# Adding 998 -> baxcalibur
# Adding 999 -> gimmighoul
# Adding 1000 -> gholdengo
# Adding 1001 -> wo-chien
# Adding 1002 -> chien-pao
# Adding 1003 -> ting-lu
# Adding 1004 -> chi-yu
# Adding 1005 -> roaring-moon
# Adding 1006 -> iron-valiant
# Adding 1007 -> koraidon
# Adding 1008 -> miraidon
# Adding 1009 -> walking-wake
# Adding 1010 -> iron-leaves
# Adding 1011 -> dipplin
# Adding 1012 -> poltchageist
# Adding 1013 -> sinistcha
# Adding 1014 -> okidogi
# Adding 1015 -> munkidori
# Adding 1016 -> fezandipiti
# Adding 1017 -> ogerpon
# Adding 1018 -> archaludon
# Adding 1019 -> hydrapple
# Adding 1020 -> gouging-fire
# Adding 1021 -> raging-bolt
# Adding 1022 -> iron-boulder
# Adding 1023 -> iron-crown
# Adding 1024 -> terapagos
# Adding 1025 -> pecharunt
# Adding 1026 -> deoxys-attack
# Adding 1027 -> deoxys-defense
# Adding 1028 -> deoxys-speed
# Adding 1029 -> wormadam-sandy
# Adding 1030 -> wormadam-trash
# Adding 1031 -> shaymin-sky
# Adding 1032 -> giratina-origin
# Adding 1033 -> rotom-heat
# Adding 1034 -> rotom-wash
# Adding 1035 -> rotom-frost
# Adding 1036 -> rotom-fan
# Adding 1037 -> rotom-mow
# Adding 1038 -> castform-sunny
# Adding 1039 -> castform-rainy
# Adding 1040 -> castform-snowy
# Adding 1041 -> basculin-blue-striped
# Adding 1042 -> darmanitan-zen
# Adding 1043 -> meloetta-pirouette
# Adding 1044 -> tornadus-therian
# Adding 1045 -> thundurus-therian
# Adding 1046 -> landorus-therian
# Adding 1047 -> kyurem-black
# Adding 1048 -> kyurem-white
# Adding 1049 -> keldeo-resolute
# Adding 1050 -> meowstic-female
# Adding 1051 -> aegislash-blade
# Adding 1052 -> pumpkaboo-small
# Adding 1053 -> pumpkaboo-large
# Adding 1054 -> pumpkaboo-super
# Adding 1055 -> gourgeist-small
# Adding 1056 -> gourgeist-large
# Adding 1057 -> gourgeist-super
# Adding 1058 -> venusaur-mega
# Adding 1059 -> charizard-mega-x
# Adding 1060 -> charizard-mega-y
# Adding 1061 -> blastoise-mega
# Adding 1062 -> alakazam-mega
# Adding 1063 -> gengar-mega
# Adding 1064 -> kangaskhan-mega
# Adding 1065 -> pinsir-mega
# Adding 1066 -> gyarados-mega
# Adding 1067 -> aerodactyl-mega
# Adding 1068 -> mewtwo-mega-x
# Adding 1069 -> mewtwo-mega-y
# Adding 1070 -> ampharos-mega
# Adding 1071 -> scizor-mega
# Adding 1072 -> heracross-mega
# Adding 1073 -> houndoom-mega
# Adding 1074 -> tyranitar-mega
# Adding 1075 -> blaziken-mega
# Adding 1076 -> gardevoir-mega
# Adding 1077 -> mawile-mega
# Adding 1078 -> aggron-mega
# Adding 1079 -> medicham-mega
# Adding 1080 -> manectric-mega
# Adding 1081 -> banette-mega
# Adding 1082 -> absol-mega
# Adding 1083 -> garchomp-mega
# Adding 1084 -> lucario-mega
# Adding 1085 -> abomasnow-mega
# Adding 1086 -> floette-eternal
# Adding 1087 -> latias-mega
# Adding 1088 -> latios-mega
# Adding 1089 -> swampert-mega
# Adding 1090 -> sceptile-mega
# Adding 1091 -> sableye-mega
# Adding 1092 -> altaria-mega
# Adding 1093 -> gallade-mega
# Adding 1094 -> audino-mega
# Adding 1095 -> sharpedo-mega
# Adding 1096 -> slowbro-mega
# Adding 1097 -> steelix-mega
# Adding 1098 -> pidgeot-mega
# Adding 1099 -> glalie-mega
# Adding 1100 -> diancie-mega
# Adding 1101 -> metagross-mega
# Adding 1102 -> kyogre-primal
# Adding 1103 -> groudon-primal
# Adding 1104 -> rayquaza-mega
# Adding 1105 -> pikachu-rock-star
# Adding 1106 -> pikachu-belle
# Adding 1107 -> pikachu-pop-star
# Adding 1108 -> pikachu-phd
# Adding 1109 -> pikachu-libre
# Adding 1110 -> pikachu-cosplay
# Adding 1111 -> hoopa-unbound
# Adding 1112 -> camerupt-mega
# Adding 1113 -> lopunny-mega
# Adding 1114 -> salamence-mega
# Adding 1115 -> beedrill-mega
# Adding 1116 -> rattata-alola
# Adding 1117 -> raticate-alola
# Adding 1118 -> raticate-totem-alola
# Adding 1119 -> pikachu-original-cap
# Adding 1120 -> pikachu-hoenn-cap
# Adding 1121 -> pikachu-sinnoh-cap
# Adding 1122 -> pikachu-unova-cap
# Adding 1123 -> pikachu-kalos-cap
# Adding 1124 -> pikachu-alola-cap
# Adding 1125 -> raichu-alola
# Adding 1126 -> sandshrew-alola
# Adding 1127 -> sandslash-alola
# Adding 1128 -> vulpix-alola
# Adding 1129 -> ninetales-alola
# Adding 1130 -> diglett-alola
# Adding 1131 -> dugtrio-alola
# Adding 1132 -> meowth-alola
# Adding 1133 -> persian-alola
# Adding 1134 -> geodude-alola
# Adding 1135 -> graveler-alola
# Adding 1136 -> golem-alola
# Adding 1137 -> grimer-alola
# Adding 1138 -> muk-alola
# Adding 1139 -> exeggutor-alola
# Adding 1140 -> marowak-alola
# Adding 1141 -> greninja-battle-bond
# Adding 1142 -> greninja-ash
# Adding 1143 -> zygarde-10-power-construct
# Adding 1144 -> zygarde-50-power-construct
# Adding 1145 -> zygarde-complete
# Adding 1146 -> gumshoos-totem
# Adding 1147 -> vikavolt-totem
# Adding 1148 -> oricorio-pom-pom
# Adding 1149 -> oricorio-pau
# Adding 1150 -> oricorio-sensu
# Adding 1151 -> lycanroc-midnight
# Adding 1152 -> wishiwashi-school
# Adding 1153 -> lurantis-totem
# Adding 1154 -> salazzle-totem
# Adding 1155 -> minior-orange-meteor
# Adding 1156 -> minior-yellow-meteor
# Adding 1157 -> minior-green-meteor
# Adding 1158 -> minior-blue-meteor
# Adding 1159 -> minior-indigo-meteor
# Adding 1160 -> minior-violet-meteor
# Adding 1161 -> minior-red
# Adding 1162 -> minior-orange
# Adding 1163 -> minior-yellow
# Adding 1164 -> minior-green
# Adding 1165 -> minior-blue
# Adding 1166 -> minior-indigo
# Adding 1167 -> minior-violet
# Adding 1168 -> mimikyu-busted
# Adding 1169 -> mimikyu-totem-disguised
# Adding 1170 -> mimikyu-totem-busted
# Adding 1171 -> kommo-o-totem
# Adding 1172 -> magearna-original
# Adding 1173 -> pikachu-partner-cap
# Adding 1174 -> marowak-totem
# Adding 1175 -> ribombee-totem
# Adding 1176 -> rockruff-own-tempo
# Adding 1177 -> lycanroc-dusk
# Adding 1178 -> araquanid-totem
# Adding 1179 -> togedemaru-totem
# Adding 1180 -> necrozma-dusk
# Adding 1181 -> necrozma-dawn
# Adding 1182 -> necrozma-ultra
# Adding 1183 -> pikachu-starter
# Adding 1184 -> eevee-starter
# Adding 1185 -> pikachu-world-cap
# Adding 1186 -> meowth-galar
# Adding 1187 -> ponyta-galar
# Adding 1188 -> rapidash-galar
# Adding 1189 -> slowpoke-galar
# Adding 1190 -> slowbro-galar
# Adding 1191 -> farfetchd-galar
# Adding 1192 -> weezing-galar
# Adding 1193 -> mr-mime-galar
# Adding 1194 -> articuno-galar
# Adding 1195 -> zapdos-galar
# Adding 1196 -> moltres-galar
# Adding 1197 -> slowking-galar
# Adding 1198 -> corsola-galar
# Adding 1199 -> zigzagoon-galar
# Adding 1200 -> linoone-galar
# Adding 1201 -> darumaka-galar
# Adding 1202 -> darmanitan-galar-standard
# Adding 1203 -> darmanitan-galar-zen
# Adding 1204 -> yamask-galar
# Adding 1205 -> stunfisk-galar
# Adding 1206 -> zygarde-10
# Adding 1207 -> cramorant-gulping
# Adding 1208 -> cramorant-gorging
# Adding 1209 -> toxtricity-low-key
# Adding 1210 -> eiscue-noice
# Adding 1211 -> indeedee-female
# Adding 1212 -> morpeko-hangry
# Adding 1213 -> zacian-crowned
# Adding 1214 -> zamazenta-crowned
# Adding 1215 -> eternatus-eternamax
# Adding 1216 -> urshifu-rapid-strike
# Adding 1217 -> zarude-dada
# Adding 1218 -> calyrex-ice
# Adding 1219 -> calyrex-shadow
# Adding 1220 -> venusaur-gmax
# Adding 1221 -> charizard-gmax
# Adding 1222 -> blastoise-gmax
# Adding 1223 -> butterfree-gmax
# Adding 1224 -> pikachu-gmax
# Adding 1225 -> meowth-gmax
# Adding 1226 -> machamp-gmax
# Adding 1227 -> gengar-gmax
# Adding 1228 -> kingler-gmax
# Adding 1229 -> lapras-gmax
# Adding 1230 -> eevee-gmax
# Adding 1231 -> snorlax-gmax
# Adding 1232 -> garbodor-gmax
# Adding 1233 -> melmetal-gmax
# Adding 1234 -> rillaboom-gmax
# Adding 1235 -> cinderace-gmax
# Adding 1236 -> inteleon-gmax
# Adding 1237 -> corviknight-gmax
# Adding 1238 -> orbeetle-gmax
# Adding 1239 -> drednaw-gmax
# Adding 1240 -> coalossal-gmax
# Adding 1241 -> flapple-gmax
# Adding 1242 -> appletun-gmax
# Adding 1243 -> sandaconda-gmax
# Adding 1244 -> toxtricity-amped-gmax
# Adding 1245 -> centiskorch-gmax
# Adding 1246 -> hatterene-gmax
# Adding 1247 -> grimmsnarl-gmax
# Adding 1248 -> alcremie-gmax
# Adding 1249 -> copperajah-gmax
# Adding 1250 -> duraludon-gmax
# Adding 1251 -> urshifu-single-strike-gmax
# Adding 1252 -> urshifu-rapid-strike-gmax
# Adding 1253 -> toxtricity-low-key-gmax
# Adding 1254 -> growlithe-hisui
# Adding 1255 -> arcanine-hisui
# Adding 1256 -> voltorb-hisui
# Adding 1257 -> electrode-hisui
# Adding 1258 -> typhlosion-hisui
# Adding 1259 -> qwilfish-hisui
# Adding 1260 -> sneasel-hisui
# Adding 1261 -> samurott-hisui
# Adding 1262 -> lilligant-hisui
# Adding 1263 -> zorua-hisui
# Adding 1264 -> zoroark-hisui
# Adding 1265 -> braviary-hisui
# Adding 1266 -> sliggoo-hisui
# Adding 1267 -> goodra-hisui
# Adding 1268 -> avalugg-hisui
# Adding 1269 -> decidueye-hisui
# Adding 1270 -> dialga-origin
# Adding 1271 -> palkia-origin
# Adding 1272 -> basculin-white-striped
# Adding 1273 -> basculegion-female
# Adding 1274 -> enamorus-therian
# Adding 1275 -> tauros-paldea-combat-breed
# Adding 1276 -> tauros-paldea-blaze-breed
# Adding 1277 -> tauros-paldea-aqua-breed
# Adding 1278 -> wooper-paldea
# Adding 1279 -> oinkologne-female
# Adding 1280 -> dudunsparce-three-segment
# Adding 1281 -> palafin-hero
# Adding 1282 -> maushold-family-of-three
# Adding 1283 -> tatsugiri-droopy
# Adding 1284 -> tatsugiri-stretchy
# Adding 1285 -> squawkabilly-blue-plumage
# Adding 1286 -> squawkabilly-yellow-plumage
# Adding 1287 -> squawkabilly-white-plumage
# Adding 1288 -> gimmighoul-roaming
# Adding 1289 -> koraidon-limited-build
# Adding 1290 -> koraidon-sprinting-build
# Adding 1291 -> koraidon-swimming-build
# Adding 1292 -> koraidon-gliding-build
# Adding 1293 -> miraidon-low-power-mode
# Adding 1294 -> miraidon-drive-mode
# Adding 1295 -> miraidon-aquatic-mode
# Adding 1296 -> miraidon-glide-mode
# Adding 1297 -> ursaluna-bloodmoon
# Adding 1298 -> ogerpon-wellspring-mask
# Adding 1299 -> ogerpon-hearthflame-mask
# Adding 1300 -> ogerpon-cornerstone-mask
# Adding 1301 -> terapagos-terastal
# Adding 1302 -> terapagos-stellar

# %%
df = pd.DataFrame(pokemon_data)

# %%
df
# Out:
#                           name  weight  hp  attack  defense  special_attack  \
# 0                    bulbasaur      69  45      49       49              65
# 1                      ivysaur     130  60      62       63              80
# 2                     venusaur    1000  80      82       83             100
# 3                   charmander      85  39      52       43              60
# 4                   charmeleon     190  58      64       58              80
# ...                        ...     ...  ..     ...      ...             ...
# 1297   ogerpon-wellspring-mask     398  80     120       84              60
# 1298  ogerpon-hearthflame-mask     398  80     120       84              60
# 1299  ogerpon-cornerstone-mask     398  80     120       84              60
# 1300        terapagos-terastal     160  95      95      110             105
# 1301         terapagos-stellar     770  95      95      110             105
#
#       special_defense  speed             type
# 0                  65     45  [grass, poison]
# 1                  80     60  [grass, poison]
# 2                 100     80  [grass, poison]
# 3                  50     65           [fire]
# 4                  65     80           [fire]
# ...               ...    ...              ...
# 1297               96    110   [grass, water]
# 1298               96    110    [grass, fire]
# 1299               96    110    [grass, rock]
# 1300              110     85         [normal]
# 1301              110     85         [normal]
#
# [1302 rows x 9 columns]

# %%
prob = pulp.LpProblem("Pokemon-Team-Optimization", pulp.LpMaximize)

# %%
x = pulp.LpVariable.dicts("x", range(len(pokemon_data)), cat='Binary')

# %%
prob += pulp.lpSum(
    (pokemon['hp'] + pokemon['attack'] + pokemon['defense'] + pokemon['special_attack'] + pokemon['special_defense'] + 
     pokemon['speed']) * x[i] for i, pokemon in enumerate(pokemon_data)
), "Total Combat Effectiveness"

# %%
# total weight constraint
max_weight_capacity = 1000
prob += pulp.lpSum(pokemon['weight'] * x[i] for i, pokemon in enumerate(pokemon_data)) <= max_weight_capacity, "Weight Capacity"

# total number of Pokemon constraint
prob += pulp.lpSum(x[i] for i in range(len(pokemon_data))) == 6, "Team Size"

# %%
prob.solve()
# Out:
# 1

# %%
selected_pokemon = [pokemon_data[i]['name'] for i in range(len(pokemon_data)) if pulp.value(x[i]) == 1]
print("Selected Pokémon:", selected_pokemon)
# Out:
# Selected Pokémon: ['jirachi', 'meloetta-aria', 'pecharunt', 'mewtwo-mega-y', 'diancie-mega', 'eternatus-eternamax']

# %%
# Calculate BST for all Pokémon
for pokemon in pokemon_data:
    pokemon['BST'] = (pokemon['hp'] + pokemon['attack'] + pokemon['defense'] +
                                             pokemon['special_attack'] + pokemon['special_defense'] + 
                                             pokemon['speed'])
    
all_pokemon_df = pd.DataFrame(pokemon_data)
selected_df = pd.DataFrame(selected_pokemon)

# Create the scatter plot
import plotly.graph_objects as go
fig = go.Figure()

# Add all Pokémon
fig.add_trace(go.Scatter(
    x=all_pokemon_df['weight'],
    y=all_pokemon_df['BST'],
    mode='markers',
    name='All Pokémon',
    marker=dict(size=10, color='blue', opacity=0.6),
    text=all_pokemon_df['name']
))

# Add selected Pokémon
fig.add_trace(go.Scatter(
    x=selected_df['weight'],
    y=selected_df['total_combat_effectiveness'],
    mode='markers',
    name='Selected Pokémon',
    marker=dict(size=12, color='red', opacity=0.9),
    text=selected_df['name']
))

# Add title and labels, resize
fig.update_layout(
    title="Pokémon Selection Optimization",
    xaxis_title="Weight (KGs)",
    yaxis_title="BST",
    legend_title="Legend",
    width=1000, 
    height=600,
    showlegend=True
)

# Show the plot
fig.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 26
#      15 fig.add_trace(go.Scatter(
#      16     x=all_pokemon_df['weight'],
#      17     y=all_pokemon_df['BST'],
#    (...)
#      21     text=all_pokemon_df['name']
#      22 ))
#      24 # Add selected Pokémon
#      25 fig.add_trace(go.Scatter(
# ---> 26     x=selected_df['weight'],
#      27     y=selected_df['total_combat_effectiveness'],
#      28     mode='markers',
#      29     name='Selected Pokémon',
#      30     marker=dict(size=12, color='red', opacity=0.9),
#      31     text=selected_df['name']
#      32 ))
#      34 # Add title and labels, resize
#      35 fig.update_layout(
#      36     title="Pokémon Selection Optimization",
#      37     xaxis_title="Weight (KGs)",
#    (...)
#      42     showlegend=True
#      43 )
#
# File D:\WORKSPACE\GitHub\shortthirdman\DataScience-Jupyter-Notebooks\dev\Lib\site-packages\pandas\core\frame.py:4102, in DataFrame.__getitem__(self, key)
#    4100 if self.columns.nlevels > 1:
#    4101     return self._getitem_multilevel(key)
# -> 4102 indexer = self.columns.get_loc(key)
#    4103 if is_integer(indexer):
#    4104     indexer = [indexer]
#
# File D:\WORKSPACE\GitHub\shortthirdman\DataScience-Jupyter-Notebooks\dev\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'weight'
